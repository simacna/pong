# %%
import requests, pprint
from bs4 import BeautifulSoup
import sys

def fetch_search_results(query=None, minAsk=None, maxAsk=None, bedrooms=None):
    search_params = {
        key: val for key, val in locals().items() if val is not None #locals() returns dictionary of current namespaces
    }
    if not search_params:
        raise ValueError("No valid keywords")

    base = 'https://newyork.craigslist.org/search/aap'
    resp = requests.get(base, params=search_params, timeout=3)
    resp.raise_for_status()  # <- no-op if status==200
    return resp.content, resp.encoding

def parse_source(html, encoding='utf-8'):
    parsed = BeautifulSoup(html, from_encoding=encoding)
    return parsed

def extract_listings(parsed): 
    """Returning a list of individual listings
    """
    #location_attrs = {'data-latitude': True, 'data-longitude': True} --- CL no longer has attrs lat/long
    listings = parsed.find_all('p', class_='row') #find_all is a beautifulsoup method
    extracted = []
    for listing in listings:
        #location = {key: listing.attrs.get(key, '') for key in location_attrs}
        link = listing.find('span', class_='pl').find('a')
        this_listing = {
            #'location': location,
            'link': link.attrs['href'],
            'description': link.string.strip()
        }
        extracted.append(this_listing)
    return extracted


if __name__ == '__main__':
    if len(sys.argv) > 1 and sys.argv[1] == 'test': #sys.argv[1] is first argument after the script
        html, encoding = read_search_results()
    else:
        html, encoding = fetch_search_results(
            minAsk=1500, maxAsk=6000, bedrooms=2
        )
    doc = parse_source(html, encoding)
    listings = extract_listings(doc)
#     print len(listings)
#     print listings
#     pprint.pprint(listings)
    print doc.prettify(encoding=encoding)
# Out:
# 100
# [{'link': '/brk/abo/5284702002.html', 'description': u'STUNNING APARTMENT, SUPER LOCATION, CLOSE TO THE PRATT INSTITUTE,'}, {'link': '/mnh/fee/5284745753.html', 'description': u'*Gorgeous3BR&2Bath Beckoning YOU! Huge CommonArea/Express Train/Best!!'}, {'link': '/brk/abo/5279662048.html', 'description': u'3 Bedrooms Greene Avenue'}, {'link': '/brk/abo/5284674264.html', 'description': u"Gorgeous BED STUY! HUGE P. DECK.! no fee. off the A C. MIN' TO THE CITY. H/HW IN"}, {'link': '/mnh/nfb/5284745022.html', 'description': u'NO FEE FURNISHED APT- PERFECT FOR TWO ROOMMATES'}, {'link': '/brk/abo/5279659407.html', 'description': u'2 Bedrooms Knickerbocker Ave'}, {'link': '/brk/abo/5284674214.html', 'description': u'WONDERFUL 4BR__MODERN KITCHEN__GREAT LIGHT FIXTURES__CENTRAL H/AC'}, {'link': '/stn/abo/5284701611.html', 'description': u'3 bedroom All Utilities BEAUTIFUL HOME! MUST SEE! WONT LAST!!!'}, {'link': '/brk/abo/5280501333.html', 'description': u'\u2650 Simply Awesome! Great 2 Bedroom - Super Location - No Fee! \u2650'}, {'link': '/mnh/abo/5284729572.html', 'description': u'89-2nd-Share real 2bdrms-w/up-great space'}, {'link': '/mnh/abo/5270457564.html', 'description': u'NO FEE----LOVELY CONVERTIBLE 3 BED!!!'}, {'link': '/brk/abo/5284656038.html', 'description': u'NEW 2BR __WD / DISHWASHER __PRIVATE DECK___DEKALB L___NO FEE'}, {'link': '/mnh/abo/5276628185.html', 'description': u'Sunny 2BR in Wash. Hts., New Appliances, Elevator, (NO FEES!)'}, {'link': '/brx/abo/5284674706.html', 'description': u'3 Bedrooms Grand Concourse'}, {'link': '/mnh/abo/5271947125.html', 'description': u'Back On Market! XL True 1 Bed Apt! Doorman Elevator Laundry Gym BLDG'}, {'link': '/brk/abo/5284641433.html', 'description': u'Newly renovated 2 br apt~~No brokers fee~~(G) train'}, {'link': '/brk/abo/5284692579.html', 'description': u'STUNNING SPACIOUS APARTMENT, CLOSE TO THE PRATT INSTITUTE, LAUNDRY,'}, {'link': '/mnh/fee/5284735103.html', 'description': u"Pet's ok ! Real 2 LG Bed.. $2500.. Call 347-806-6219"}, {'link': '/mnh/abo/5265789470.html', 'description': u'Great 2br apt- H\\H water inc- by 6 train !!'}, {'link': '/brk/abo/5279653197.html', 'description': u'4 Bedrooms Knickerbocker Ave'}, {'link': '/mnh/abo/5279851367.html', 'description': u'Great 2br apt ~ h\\h water inc ~ by Costco ~ by Jefferson park!'}, {'link': '/que/abo/5284683598.html', 'description': u'YOU CAN OWN 1 FAMILY / DRIVEWAY / DETACHED / FULLY RENOVATED'}, {'link': '/mnh/abo/5280003409.html', 'description': u'By 6 train - 2br apartment - h\\h water inc - call mow !'}, {'link': '/mnh/abo/5280084396.html', 'description': u'Great 2br apt ~ h\\h water inc ~ by Costco ~ ..!'}, {'link': '/mnh/abo/5279957520.html', 'description': u'Great deal! Newly renovated 2br apartment - short walk to 6 train!'}, {'link': '/mnh/abo/5280020310.html', 'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !'}, {'link': '/mnh/abo/5280015015.html', 'description': u'GREAT LOCATION - NEWLY RENOVATED 2BR APT - BY 6 TRAIN!!'}, {'link': '/mnh/abo/5258063139.html', 'description': u'Amazing three bedroom two bath! Absolute steal'}, {'link': '/mnh/abo/5258344060.html', 'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train!'}, {'link': '/brk/abo/5276651627.html', 'description': u'___BRAND NEW___LUXUARY___DESIGNED___ W/ WASHER DRYER___& CENTRAL A C__'}, {'link': '/brk/abo/5284664537.html', 'description': u'HOT STUFF __HUGE SPACE 4BR/1,5BATH MASSIVE APT __BRAND NEW __L M TRAINS'}, {'link': '/brk/abo/5279650768.html', 'description': u'2 Bedrooms Greene Avenue'}, {'link': '/mnh/abo/5279937777.html', 'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !'}, {'link': '/mnh/abo/5280094071.html', 'description': u'2BR APARTMENT ~HEAT \\ HOT WATER INCLUDED !'}, {'link': '/mnh/abo/5279962396.html', 'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !'}, {'link': '/mnh/abo/5279972914.html', 'description': u'PERFECT 3BR APT!!! NEW ...
# [{'description': u'STUNNING APARTMENT, SUPER LOCATION, CLOSE TO THE PRATT INSTITUTE,',
#   'link': '/brk/abo/5284702002.html'},
#  {'description': u'*Gorgeous3BR&2Bath Beckoning YOU! Huge CommonArea/Express Train/Best!!',
#   'link': '/mnh/fee/5284745753.html'},
#  {'description': u'3 Bedrooms Greene Avenue',
#   'link': '/brk/abo/5279662048.html'},
#  {'description': u"Gorgeous BED STUY! HUGE P. DECK.! no fee. off the A C. MIN' TO THE CITY. H/HW IN",
#   'link': '/brk/abo/5284674264.html'},
#  {'description': u'NO FEE FURNISHED APT- PERFECT FOR TWO ROOMMATES',
#   'link': '/mnh/nfb/5284745022.html'},
#  {'description': u'2 Bedrooms Knickerbocker Ave',
#   'link': '/brk/abo/5279659407.html'},
#  {'description': u'WONDERFUL 4BR__MODERN KITCHEN__GREAT LIGHT FIXTURES__CENTRAL H/AC',
#   'link': '/brk/abo/5284674214.html'},
#  {'description': u'3 bedroom All Utilities BEAUTIFUL HOME! MUST SEE! WONT LAST!!!',
#   'link': '/stn/abo/5284701611.html'},
#  {'description': u'\u2650 Simply Awesome! Great 2 Bedroom - Super Location - No Fee! \u2650',
#   'link': '/brk/abo/5280501333.html'},
#  {'description': u'89-2nd-Share real 2bdrms-w/up-great space',
#   'link': '/mnh/abo/5284729572.html'},
#  {'description': u'NO FEE----LOVELY CONVERTIBLE 3 BED!!!',
#   'link': '/mnh/abo/5270457564.html'},
#  {'description': u'NEW 2BR __WD / DISHWASHER __PRIVATE DECK___DEKALB L___NO FEE',
#   'link': '/brk/abo/5284656038.html'},
#  {'description': u'Sunny 2BR in Wash. Hts., New Appliances, Elevator, (NO FEES!)',
#   'link': '/mnh/abo/5276628185.html'},
#  {'description': u'3 Bedrooms Grand Concourse',
#   'link': '/brx/abo/5284674706.html'},
#  {'description': u'Back On Market! XL True 1 Bed Apt! Doorman Elevator Laundry Gym BLDG',
#   'link': '/mnh/abo/5271947125.html'},
#  {'description': u'Newly renovated 2 br apt~~No brokers fee~~(G) train',
#   'link': '/brk/abo/5284641433.html'},
#  {'description': u'STUNNING SPACIOUS APARTMENT, CLOSE TO THE PRATT INSTITUTE, LAUNDRY,',
#   'link': '/brk/abo/5284692579.html'},
#  {'description': u"Pet's ok ! Real 2 LG Bed.. $2500.. Call 347-806-6219",
#   'link': '/mnh/fee/5284735103.html'},
#  {'description': u'Great 2br apt- H\\H water inc- by 6 train !!',
#   'link': '/mnh/abo/5265789470.html'},
#  {'description': u'4 Bedrooms Knickerbocker Ave',
#   'link': '/brk/abo/5279653197.html'},
#  {'description': u'Great 2br apt ~ h\\h water inc ~ by Costco ~ by Jefferson park!',
#   'link': '/mnh/abo/5279851367.html'},
#  {'description': u'YOU CAN OWN 1 FAMILY / DRIVEWAY / DETACHED / FULLY RENOVATED',
#   'link': '/que/abo/5284683598.html'},
#  {'description': u'By 6 train - 2br apartment - h\\h water inc - call mow !',
#   'link': '/mnh/abo/5280003409.html'},
#  {'description': u'Great 2br apt ~ h\\h water inc ~ by Costco ~ ..!',
#   'link': '/mnh/abo/5280084396.html'},
#  {'description': u'Great deal! Newly renovated 2br apartment - short walk to 6 train!',
#   'link': '/mnh/abo/5279957520.html'},
#  {'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !',
#   'link': '/mnh/abo/5280020310.html'},
#  {'description': u'GREAT LOCATION - NEWLY RENOVATED 2BR APT - BY 6 TRAIN!!',
#   'link': '/mnh/abo/5280015015.html'},
#  {'description': u'Amazing three bedroom two bath! Absolute steal',
#   'link': '/mnh/abo/5258063139.html'},
#  {'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train!',
#   'link': '/mnh/abo/5258344060.html'},
#  {'description': u'___BRAND NEW___LUXUARY___DESIGNED___ W/ WASHER DRYER___& CENTRAL A C__',
#   'link': '/brk/abo/5276651627.html'},
#  {'description': u'HOT STUFF __HUGE SPACE 4BR/1,5BATH MASSIVE APT __BRAND NEW __L M TRAINS',
#   'link': '/brk/abo/5284664537.html'},
#  {'description': u'2 Bedrooms Greene Avenue',
#   'link': '/brk/abo/5279650768.html'},
#  {'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !',
#   'link': '/mnh/abo/5279937777.html'},
#  {'description': u'2BR APARTMENT ~HEAT \\ HOT WATER INCLUDED !',
#   'link': '/mnh/abo/5280094071.html'},
#  {'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !',
#   'link': '/mnh/abo/5279962396.html'},
#  {'description': u'PERFECT 3BR APT!!! NEWLY FULLY RENO- H\\H WATER INC- BY 6 TRAIN!',
#   'link': '/mnh/abo/5279972914.html'},
#  {'description': u'Massive 2 Br * L M Trains * Huge Space * Sunny * EXPOSED BRICK * LOOK',
#   'link': '/brk/abo/5278063917.html'},
#  {'description': u'%% NO FEE SPACIOUS CON. 2 BDRM W/D UNIT QUEEN SZ BDRMS %%',
#   'link': '/mnh/abo/5281539838.html'},
#  {'description': u'! AMAZING 2BDRM 2BTH GREAT VIEWS SUNLIGHT MUST SEE !',
#   'link': '/mnh/abo/5281569300.html'},
#  {'description': u'Very Very Spacious 2 Bdrm W/ Tile Floor In Kitchen & Entry Area',
#   'link': '/brx/abo/5275868031.html'},
#  {'description': u'* CHELSEA PENTHOUSE 2 BDRM 2 FULL BATH W/D UNIT PRIVATE ROOF DECK !',
#   'link': '/mnh/abo/5281645394.html'},
#  {'description': u'Hampton Bays year round rental',
#   'link': '/lgi/abo/5284729693.html'},
#  {'description': u'ENORMOUS 5 Bedroom Loft -- Amazing Rooftop -- NO FEE!',
#   'link': '/brk/abo/5279274995.html'},
#  {'description': u'2BR APARTMENT ~HEAT \\ HOT WATER INCLUDED ~ SHORT WALK TO 6 TRAIN!',
#   'link': '/mnh/abo/5274983734.html'},
#  {'description': u'HUuuuuGGee***FLEX 3***back yard***PERFECT SHARE>>',
#   'link': '/mnh/abo/5284660058.html'},
#  {'description': u'SEE THIS SUPERB 2BR-=-NICE FINISHING FRM TOP TO BOTTOM-=HIGH CEILING',
#   'link': '/brk/abo/5284666381.html'},
#  {'description': u'AMAZING 3BR******NEWLY RENO******GREAT SIZE & LOCATION!! A MUST SEE',
#   'link': '/brk/abo/5284637663.html'},
#  {'description': u'GREAT LOCATION ~2br ~HEAT \\ HOT WATER INCLUDED ~ NO BROKER FEE!',
#   'link': '/mnh/abo/5256573088.html'},
#  {'description': u'GUT RENOVATED 3BR - Central AC - Dishwasher - Everything New!!',
#   'link': '/brk/abo/5266899459.html'},
#  {'description': u'Renovated Garden Apt', 'link': '/brk/abo/5284725577.html'},
#  {'description': u'Great 3br apartment -Great location -BY 6 TRAIN - CALL ME!',
#   'link': '/mnh/abo/5274993277.html'},
#  {'description': u'Renovated 2BR railroad by owner',
#   'link': '/brk/abo/5272359532.html'},
#  {'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !',
#   'link': '/mnh/abo/5265822486.html'},
#  {'description': u'Sunny and Spacious', 'link': '/brk/abo/5253979969.html'},
#  {'description': u'Two Bedroom with Perfect Modern Design',
#   'link': '/brx/abo/5276104288.html'},
#  {'description': u'Great location - beautiful block - 2br apt - by 6 train.',
#   'link': '/mnh/abo/5280076729.html'},
#  {'description': u'Great 2br apartment - located one block to 6 train - call now!',
#   'link': '/mnh/abo/5274976983.html'},
#  {'description': u'2BR APARTMENT ~HEAT \\ HOT WATER INCLUDED ~ BY 6 TRAIN!',
#   'link': '/mnh/abo/5258935945.html'},
#  {'description': u'Newly renovated 2br apartment ~ h\\h water inc ~ by 6 train !',
#   'link': '/mnh/abo/5265804315.html'},
#  {'description': u'Amazing three bedroom!! 1.5 bath! Will not last',
#   'link': '/mnh/abo/5278051314.html'},
#  {'description': u'MAKE THIS YOUR NEW HOME! GRAND 2BDRM + PVT PARKING + LOUNGE AREA + GYM',
#   'link': '/brk/abo/5284695639.html'},
#  {'description': u'Perfect for sharing - 3br apt - h\\h water inc - by 6 train!',
#   'link': '/mnh/abo/5265793534.html'},
#  {'description': u'perfect for students 2br apt- h\\h water inc- short walk to 6 train!',
#   'link': '/mnh/abo/5265799519.html'},
#  {'description': u'Amazing two bedroom!! steps from Columbia',
#   'link': '/mnh/abo/5257876478.html'},
#  {'description': u'HUuuuuGGee***FLEX 3***back yard***PERFECT SHARE>>',
#   'link': '/mnh/abo/5284661301.html'},
#  {'description': u'L&M@ WYCKOFF ^ 4 BEDROOMS ^ WONT LAST ^ NO BROKER FEE ^ BRIGHT& SPACIOUS',
#   'link': '/brk/abo/5284637536.html'},
#  {'description': u'Super lux in the heart of Gramercy',
#   'link': '/mnh/abo/5277301856.html'},
#  {'description': u'Super lux in the heart of Gramercy',
#   'link': '/mnh/abo/5256802845.html'},
#  {'description': u'Luxury apartment in a high-rise doorman building',
#   'link': '/mnh/abo/5266731489.html'},
#  {'description': u'NEW HIGH END 3BR/1BA MASSIVE APT --CENTRAL AC --BRAND NEW --- CJ TRAINS -NO FEE',
#   'link': '/brk/abo/5284678582.html'},
#  {'description': u'NEWLY GUTTED AND RENOVATED A BEAUTIFUL OUTSTANDING 2 BEDROOM WITH NO FEE!',
#   'link': '/brk/abo/5284655774.html'},
#  {'description': u"Looking for the perferct ''Loft''??? check this out! Right @ Subway!!",
#   'link': '/brk/abo/5275565083.html'},
#  {'description': u'Incredibly Unique 2BR / 2BA Duplex w/ Private Roof Deck - NO FEE!',
#   'link': '/brk/abo/5279266222.html'},
#  {'description': u'YOU CAN OWN 1 FAMILY / DRIVEWAY / DETACHED / FULLY RENOVATED',
#   'link': '/que/abo/5284682389.html'},
#  {'description': u'LUXURIOUS 2BR APT_SHINY HARDWOOD FLRS__MODERN BATH__BEST KITCHEN',
#   'link': '/brk/abo/5284682146.html'},
#  {'description': u'AMAZING 2BR*****BRIGHT &SUNNY***HEAT &HW***PRIME LOCATION!!',
#   'link': '/brk/abo/5284630574.html'},
#  {'description': u'WILLIAMSBURG 2BR LOFT APT ! ELEVATOR ! ROOF ! LAUNDRY !',
#   'link': '/brk/abo/5258392553.html'},
#  {'description': u'WILLIAMSBURG 3BR APT! NEXT TO THE L TRAIN ~ 2 BATHS !',
#   'link': '/brk/abo/5258396906.html'},
#  {'description': u'COME LIVE IN WILLIAMSBURG GREENPOINT !! L TRAIN!!! 3BR , LAUNDRY',
#   'link': '/brk/abo/5252960484.html'},
#  {'description': u'WILLIAMSBURG 2BR 2.5 BATH DUPLEX, DISH AND TERRACE !!! NO FEE',
#   'link': '/brk/abo/5258398626.html'},
#  {'description': u'STUNNING 2BR LOFT APT ON HIGH FLOOR !! ELEVATOR ! ROOF ! LAUNDRY!',
#   'link': '/brk/abo/5274060441.html'},
#  {'description': u'Private 3 Floor House For Rent! 4.5 Bdrm/2 Bathroom! Parking/Backyard!',
#   'link': '/brk/abo/5271180077.html'},
#  {'description': u'Price is Flexible I need Someone Right now',
#   'link': '/brk/abo/5284669814.html'},
#  {'description': u'YOU CAN OWN 1 FAMILY / DRIVEWAY / DETACHED / FULLY RENOVATED',
#   'link': '/que/abo/5256899816.html'},
#  {'description': u'ASTOUNDING NEW 3BR APT__SHINY WOOD FLRS__SKY LIGHT__SUPER HIGH CEILING',
#   'link': '/brk/abo/5284636023.html'},
#  {'description': u'HUGE, COZY 2BDs Apt. Built in Desk - 1 Left Avaialble Immediately',
#   'link': '/jsy/abo/5284674404.html'},
#  {'description': u'Large 4 BR / 1.5 BA Steps From McGolrick Park - NO FEE!',
#   'link': '/brk/abo/5279322943.html'},
#  {'description': u'2 Bedrooms Chauncey St',
#   'link': '/brk/abo/5279645705.html'},
#  {'description': u'3 box bed.rm.apt. hi end lux. huge apt. L train no fee',
#   'link': '/brk/abo/5284687609.html'},
#  {'description': u'\U0001f353Laundry on site\U0001f353Super on Site\U0001f353$100 gift card',
#   'link': '/stn/abo/5284654334.html'},
#  {'description': u'Custom Renovated 2+br / Private Yard / ALL utilites included / NO FEE',
#   'link': '/brk/abo/5284666980.html'},
#  {'description': u'By Owner - 3BR/1.5Bth Apartment',
#   'link': '/que/abo/5284689498.html'},
#  {'description': u'3 Bedrooms Stuyvesant Ave',
#   'link': '/brk/abo/5279643674.html'},
#  {'description': u'YOU CAN OWN 1 FAMILY / DRIVEWAY / DETACHED / FULLY RENOVATED',
#   'link': '/que/abo/5284685052.html'},
#  {'description': u'FABULOUS DPLX APT 3BDRM == PVT TERRACE == HUGE SPACE AREA == SS APPS',
#   'link': '/brk/abo/5284698824.html'},
#  {'description': u'Palatial Chic Crisp Like Fresh Linens 3BR+Dining Room Washer Dishwasher Details!',
#   'link': '/brk/fee/5284712958.html'},
#  {'description': u'Place to live with your buds in this B-E-A-U TIFUL Post Grad 3 Bedroom',
#   'link': '/mnh/abo/5281737806.html'},
#  {'description': u'Sunny 3 rooms and eat in kitchen in Danbury',
#   'link': '/fct/abo/5284705625.html'},
#  {'description': u'Awesome Design>">">",brand new renovation, 3 blocks',
#   'link': '/brk/abo/5271448834.html'},
#  {'description': u'3 Bedrooms Pulaski St', 'link': '/brk/abo/5279642030.html'}]
