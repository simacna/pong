# %%
import requests, pprint
from bs4 import BeautifulSoup
import sys

def fetch_search_results(query=None, minAsk=None, maxAsk=None, bedrooms=None):
    search_params = {
        key: val for key, val in locals().items() if val is not None #locals() returns dictionary of current namespaces
    }
    if not search_params:
        raise ValueError("No valid keywords")

    base = 'https://newyork.craigslist.org/search/aap'
    resp = requests.get(base, params=search_params, timeout=3)
    resp.raise_for_status()  # <- no-op if status==200
    return resp.content, resp.encoding

def parse_source(html, encoding='utf-8'):
    parsed = BeautifulSoup(html, from_encoding=encoding)
    return parsed

def extract_listings(parsed): 
    """Returning a list of individual listings
    """
    #location_attrs = {'data-latitude': True, 'data-longitude': True} --- CL no longer has attrs lat/long
    listings = parsed.find_all('p', class_='row') #find_all is a beautifulsoup method
    extracted = []
    for listing in listings:
        #location = {key: listing.attrs.get(key, '') for key in location_attrs}
        link = listing.find('span', class_='pl').find('a')
        this_listing = {
            #'location': location,
            'link': link.attrs['href'],
            'description': link.string.strip()
        }
        extracted.append(this_listing)
    return extracted


if __name__ == '__main__':
    if len(sys.argv) > 1 and sys.argv[1] == 'test': #sys.argv[1] is first argument after the script
        html, encoding = read_search_results()
    else:
        html, encoding = fetch_search_results(
            minAsk=1500, maxAsk=6000, bedrooms=2
        )
    doc = parse_source(html, encoding)
    listings = extract_listings(doc)
#     print len(listings)
#     print listings
#     pprint.pprint(listings)
    print doc.prettify(encoding=encoding)
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    new york all apartments - craigslist
#   </title>
#   <meta content="new york all apartments  - craigslist" name="description"/>
#   <link href="https://newyork.craigslist.org/search/aap" rel="canonical"/>
#   <link href="https://newyork.craigslist.org/search/aap?bedrooms=2&amp;format=rss&amp;min_price=1500" rel="alternate" title="RSS feed for craigslist | new york all apartments  - craigslist " type="application/rss+xml"/>
#   <link href="https://newyork.craigslist.org/search/aap?s=100&amp;bedrooms=2&amp;max_price=6000&amp;min_price=1500" rel="next"/>
#   <meta content="initial-scale=1.0, user-scalable=1" name="viewport"/>
#   <link href="//www.craigslist.org/styles/cl.css?v=3114bc271b08ca14f2a45ffde71b5c95" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/tocs.css?v=87979fae08a34cc05a94244af076c28a" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/jquery-ui-1.9.2.custom.css?v=86db72e37d2cf63cab3c63485c71becb" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/js/postings-concat.min.js?v=a7f5de52c8ef9cf89ab3aca6ae739c5a" rel="prefetch"/>
#   <link href="//www.craigslist.org/styles/leaflet-stock.css?v=969bf0c010aad78a472cb96ed5c1d1bc" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/MarkerCluster.css?v=c9937ed03fbb57f185493cd8c283efeb" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/tocsmaps.css?v=4b8e149bc3b9ea301df4959bc7220040" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#   <script type="text/javascript">
#    <!--
#             var defaultView = "grid";
# var expiredFavIDs = [];
# var subarea = null;
# var maxResults = 2500;
# var odaCats = {};
# var lessInfoText = "less info";
# var showMapTabs = 1;
# var areaID = "3";
# var starHint = "save this post in your favorites list";
# var sectionAbb = "hhh";
# var catAbb = "aap";
# var currencySymbol = "&#x0024;";
# var maptileBaseUrl = "//map{s}.craigslist.org/t07/{z}/{x}/{y}.png";
# var areaRegion = "NY";
# var noImageText = "no image";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var zoomToPosting = null;
# var imageHost = "http://images.craigslist.org";
# var areaCountry = "US";
# var countOfTotalText = "image {count} of {total}";
# var pID = null;
#
#         -->
#   </script>
#   <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=096822b653643ed1af3136947e4ea79a" type="text/javascript" ></script>
# <![endif]-->
#   <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=178d4ad319e0e0b4a451b15e49b71bec" type="text/javascript" ></script>
# <![endif]-->
#  </head>
#  <body class="toc search">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         var lng = C('cl_def_lang');
#         if (lng) bodyClassList.push(lng);
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section id="pagecontainer">
#    <div class="bglogo">
#    </div>
#    <header class="global-header">
#     <div class="mobile-header">
#      <div class="mobile-menu-button">
#       menu
#      </div>
#      <h2 class="mobile-logo">
#       <a class="mobile-logo-link" href="/">
#        craigslist
#       </a>
#       &gt; housing
#      </h2>
#     </div>
#     <a class="header-logo" href="https://newyork.craigslist.org">
#      CL
#     </a>
#     <div class="mobile-menu-drawer">
#      <nav class="breadcrumbs-container">
#       <form action="/search/aap" data-action="/search/###/aap" id="breadcrumbform" method="get">
#        <input name="min_price" type="hidden" value="1500"/>
#        <input name="max_price" type="hidden" value="6000"/>
#        <input name="bedrooms" type="hidden" value="2"/>
#        <ul class="breadcrumbs">
#         <li class="crumb area">
#          <label class="mobile-only submenu-text" for="areaAbb">
#           area
#          </label>
#          <span class="no-js">
#           <a href="/">
#            new york
#           </a>
#          </span>
#          <select class="js-only" id="areaAbb" name="areaAbb">
#           <option value="newyork">
#            new york
#           </option>
#           <option value="albany">
#            albany, NY
#           </option>
#           <option value="allentown">
#            allentown
#           </option>
#           <option value="altoona">
#            altoona
#           </option>
#           <option value="annapolis">
#            annapolis
#           </option>
#           <option value="baltimore">
#            baltimore
#           </option>
#           <option value="binghamton">
#            binghamton
#           </option>
#           <option value="boston">
#            boston
#           </option>
#           <option value="capecod">
#            cape cod
#           </option>
#           <option value="catskills">
#            catskills
#           </option>
#           <option value="cnj">
#            central NJ
#           </option>
#           <option value="chambersburg">
#            cumberland val
#           </option>
#           <option value="delaware">
#            delaware
#           </option>
#           <option value="newlondon">
#            eastern CT
#           </option>
#           <option value="easternshore">
#            eastern shore
#           </option>
#           <option value="martinsburg">
#            eastern WV
#           </option>
#           <option value="elmira">
#            elmira
#           </option>
#           <option value="fingerlakes">
#            finger lakes
#           </option>
#           <option value="frederick">
#            frederick
#           </option>
#           <option value="glensfalls">
#            glens falls
#           </option>
#           <option value="harrisburg">
#            harrisburg
#           </option>
#           <option value="hartford">
#            hartford
#           </option>
#           <option value="hudsonvalley">
#            hudson valley
#           </option>
#           <option value="ithaca">
#            ithaca
#           </option>
#           <option value="jerseyshore">
#            jersey shore
#           </option>
#           <option value="lancaster">
#            lancaster, PA
#           </option>
#           <option value="longisland">
#            long island
#           </option>
#           <option value="newhaven">
#            new haven
#           </option>
#           <option value="newjersey">
#            north jersey
#           </option>
#           <option value="nwct">
#            northwest CT
#           </option>
#           <option value="oneonta">
#            oneonta
#           </option>
#           <option value="philadelphia">
#            philadelphia
#           </option>
#           <option value="poconos">
#            poconos
#           </option>
#           <option value="reading">
#            reading
#           </option>
#           <option value="providence">
#            rhode island
#           </option>
#           <option value="scranton">
#            scranton
#           </option>
#           <option value="southcoast">
#            south coast
#           </option>
#           <option value="smd">
#            southern MD
#           </option>
#           <option value="southjersey">
#            south jersey
#           </option>
#           <option value="pennstate">
#            state college
#           </option>
#           <option value="syracuse">
#            syracuse
#           </option>
#           <option value="utica">
#            utica
#           </option>
#           <option value="washingtondc">
#            washington, DC
#           </option>
#           <option value="westernmass">
#            western mass
#           </option>
#           <option value="williamsport">
#            williamsport
#           </option>
#           <option value="worcester">
#            worcester
#           </option>
#           <option value="york">
#            york, PA
#           </option>
#          </select>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb subarea">
#          <label class="mobile-only submenu-text" for="subArea">
#           subarea
#          </label>
#          <select id="subArea" name="subArea">
#           <option selected="" value="">
#            all new york
#           </option>
#           <option value="brx">
#            bronx
#           </option>
#           <option value="brk">
#            brooklyn
#           </option>
#           <option value="fct">
#            fairfield
#           </option>
#           <option value="lgi">
#            long island
#           </option>
#           <option value="mnh">
#            manhattan
#           </option>
#           <option value="jsy">
#            new jersey
#           </option>
#           <option value="que">
#            queens
#           </option>
#           <option value="stn">
#            staten island
#           </option>
#           <option value="wch">
#            westchester
#           </option>
#          </select>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb section">
#          <label class="mobile-only submenu-text" for="catAbb">
#           section
#          </label>
#          <select id="catAbb" name="catAbb">
#           <option value="ccc">
#            community
#           </option>
#           <option value="eee">
#            events
#           </option>
#           <option value="sss">
#            for sale
#           </option>
#           <option value="ggg">
#            gigs
#           </option>
#           <option selected="" value="hhh">
#            housing
#           </option>
#           <option value="jjj">
#            jobs
#           </option>
#           <option value="ppp">
#            personals
#           </option>
#           <option value="rrr">
#            resumes
#           </option>
#           <option value="bbb">
#            services
#           </option>
#          </select>
#          <span class="breadcrumb-arrow">
#           &gt;
#          </span>
#         </li>
#         <li class="crumb category">
#          <div class="mobile-only breadcrumb-labels">
#           category
#          </div>
#          <select class="js-only" id="subcatAbb">
#           <option value="hhh">
#            all
#           </option>
#           <option selected="" value="aap">
#            all apartments
#           </option>
#           <option value="fee">
#            apts broker fee
#           </option>
#           <option value="nfb">
#            apts broker no fee
#           </option>
#           <option value="abo">
#            apts by owner
#           </option>
#           <option value="aiv">
#            apts registration fee
#           </option>
#           <option value="hou">
#            apts wanted
#           </option>
#           <option value="swp">
#            housing swap
#           </option>
#           <option value="off">
#            office &amp; commercial
#           </option>
#           <option value="prk">
#            parking &amp; storage
#           </option>
#           <option value="reb">
#            real estate - by broker
#           </option>
#           <option value="reo">
#            real estate - by owner
#           </option>
#           <option value="rew">
#            real estate wanted
#           </option>
#           <option value="roo">
#            rooms &amp; shares
#           </option>
#           <option value="sha">
#            rooms wanted
#           </option>
#           <option value="sub">
#            sublets &amp; temporary
#           </option>
#           <option value="sbw">
#            sublet/temp wanted
#           </option>
#           <option value="vac">
#            vacation rentals
#           </option>
#          </select>
#          <span class="no-js">
#           all apartments
#          </span>
#          <span class="no-js">
#           <input type="submit" value="go"/>
#          </span>
#         </li>
#        </ul>
#       </form>
#      </nav>
#      <ul class="userlinks">
#       <li class="user post">
#        <a class="no-mobile" href="https://post.craigslist.org/c/nyc">
#         post
#        </a>
#        <a class="mobile-only" href="https://post.craigslist.org/c/nyc">
#         post to classifieds
#        </a>
#       </li>
#       <li class="user account">
#        <span>
#         [
#        </span>
#        <a class="no-mobile" href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#        <a class="mobile-only" href="https://accounts.craigslist.org/login/home">
#         my account
#        </a>
#        <span>
#         ]
#        </span>
#       </li>
#       <li class="user fav">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span class="n">
#           0
#          </span>
#          <span class="no-mobile">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <div class="middle">
#     <form action="/search/aap" id="searchform">
#      <div class="searchbox">
#       <input id="excats" name="excats" type="hidden"/>
#       <div class="searchgroup showoptions linklike closed">
#        <div class="mobile-favorites mobile-only">
#         <div class="favorites">
#          <a class="favlink" href="#">
#           <span class="n">
#            0
#           </span>
#           <span class="no-mobile">
#            favorites
#           </span>
#          </a>
#         </div>
#        </div>
#        <span class="open">
#         –
#        </span>
#        <span class="closed">
#         +
#        </span>
#        search options
#       </div>
#       <div class="searchoptions closed">
#        <div class="searchgroup categories">
#         <div class="cattitle">
#          <a class="reset" href="/search/aap" title="clear all search parameters">
#           all apartments
#          </a>
#         </div>
#        </div>
#        <input id="is_paid" name="is_paid" type="hidden" value=""/>
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input class="autosubmit" name="srchType" type="checkbox" value="T"/>
#            search titles only
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            search nearby areas
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas ">
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="59"/>
#            albany, NY
#            <small>
#             (alb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="355"/>
#            altoona-johnstown
#            <small>
#             (aoo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="460"/>
#            annapolis
#            <small>
#             (anp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="34"/>
#            baltimore
#            <small>
#             (bal)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_60" name="nearbyArea" type="checkbox" value="483"/>
#            belleville, ON
#            <small>
#             (bel)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="248"/>
#            binghamton
#            <small>
#             (bgm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_35" name="nearbyArea" type="checkbox" value="4"/>
#            boston
#            <small>
#             (bos)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_58" name="nearbyArea" type="checkbox" value="40"/>
#            buffalo
#            <small>
#             (buf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="239"/>
#            cape cod / islands
#            <small>
#             (cap)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="451"/>
#            catskills
#            <small>
#             (cat)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input checked="checked" class="use-id" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="349"/>
#            central NJ
#            <small>
#             (cnj)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_63" name="nearbyArea" type="checkbox" value="290"/>
#            charlottesville
#            <small>
#             (uva)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_62" name="nearbyArea" type="checkbox" value="452"/>
#            chautauqua
#            <small>
#             (chq)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="481"/>
#            cornwall, ON
#            <small>
#             (ycc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_38" name="nearbyArea" type="checkbox" value="705"/>
#            cumberland valley
#            <small>
#             (cbg)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="193"/>
#            delaware
#            <small>
#             (dlw)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="281"/>
#            eastern CT
#            <small>
#             (nlo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="444"/>
#            eastern panhandle
#            <small>
#             (ewv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_29" name="nearbyArea" type="checkbox" value="328"/>
#            eastern shore
#            <small>
#             (esh)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="453"/>
#            elmira-corning
#            <small>
#             (elm)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="685"/>
#            finger lakes
#            <small>
#             (fgl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="633"/>
#            frederick
#            <small>
#             (fdk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_49" name="nearbyArea" type="checkbox" value="457"/>
#            fredericksburg
#            <small>
#             (ezf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="686"/>
#            glens falls
#            <small>
#             (gfl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="48"/>
#            hampton roads
#            <small>
#             (nfk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="166"/>
#            harrisburg
#            <small>
#             (hrs)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_10">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_64" name="nearbyArea" type="checkbox" value="447"/>
#            harrisonburg
#            <small>
#             (shd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="44"/>
#            hartford
#            <small>
#             (htf)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input checked="checked" class="use-id" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="249"/>
#            hudson valley
#            <small>
#             (hud)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_31" name="nearbyArea" type="checkbox" value="201"/>
#            ithaca
#            <small>
#             (ith)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input checked="checked" class="use-id" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="561"/>
#            jersey shore
#            <small>
#             (jys)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_54" name="nearbyArea" type="checkbox" value="385"/>
#            kingston, ON
#            <small>
#             (kng)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="279"/>
#            lancaster, PA
#            <small>
#             (lns)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="167"/>
#            lehigh valley
#            <small>
#             (alt)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input checked="checked" class="use-id" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="250"/>
#            long island
#            <small>
#             (isp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_46" name="nearbyArea" type="checkbox" value="198"/>
#            new hampshire
#            <small>
#             (nhm)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input checked="checked" class="use-id" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="168"/>
#            new haven
#            <small>
#             (hvn)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input checked="checked" class="use-id" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="170"/>
#            north jersey
#            <small>
#             (njy)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="354"/>
#            northwest CT
#            <small>
#             (nct)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="684"/>
#            oneonta
#            <small>
#             (onh)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="17"/>
#            philadelphia
#            <small>
#             (phi)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_55" name="nearbyArea" type="checkbox" value="338"/>
#            plattsburgh-adirondacks
#            <small>
#             (plb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="356"/>
#            poconos
#            <small>
#             (poc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="683"/>
#            potsdam-canton-massena
#            <small>
#             (ptd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="278"/>
#            reading
#            <small>
#             (rea)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="38"/>
#            rhode island
#            <small>
#             (prv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_9">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="60"/>
#            richmond, VA
#            <small>
#             (ric)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_50" name="nearbyArea" type="checkbox" value="126"/>
#            rochester, NY
#            <small>
#             (rcs)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="276"/>
#            scranton / wilkes-barre
#            <small>
#             (avp)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="378"/>
#            south coast
#            <small>
#             (sma)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_43" name="nearbyArea" type="checkbox" value="556"/>
#            southern maryland
#            <small>
#             (smd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="286"/>
#            south jersey
#            <small>
#             (snj)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="277"/>
#            state college
#            <small>
#             (psu)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="130"/>
#            syracuse
#            <small>
#             (syr)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_53" name="nearbyArea" type="checkbox" value="704"/>
#            twin tiers NY/PA
#            <small>
#             (tts)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_5">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="247"/>
#            utica-rome-oneida
#            <small>
#             (uti)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_52" name="nearbyArea" type="checkbox" value="93"/>
#            vermont
#            <small>
#             (brl)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_6">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_41" name="nearbyArea" type="checkbox" value="10"/>
#            washington, DC
#            <small>
#             (wdc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_48" name="nearbyArea" type="checkbox" value="337"/>
#            watertown
#            <small>
#             (wtn)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_8">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="329"/>
#            western maryland
#            <small>
#             (wmd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="173"/>
#            western massachusetts
#            <small>
#             (wma)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_26" name="nearbyArea" type="checkbox" value="463"/>
#            williamsport
#            <small>
#             (wpt)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_7">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_47" name="nearbyArea" type="checkbox" value="711"/>
#            winchester
#            <small>
#             (okv)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_4">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="240"/>
#            worcester / central MA
#            <small>
#             (wor)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="357"/>
#            york, PA
#            <small>
#             (yrk)
#            </small>
#           </label>
#          </li>
#          <li>
#           <span class="nextNearbyZone linklike" data-zone="1">
#            + show
#            <span id="nearbyNumber">
#             59
#            </span>
#            more...
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup minmax ">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value="1500"/>
#         <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value="6000"/>
#        </div>
#        <div class="searchgroup">
#         <select class="autosubmit" name="bedrooms">
#          <option value="">
#           all bedrooms
#          </option>
#          <option value="1">
#           1+ bedrooms
#          </option>
#          <option selected="selected" value="2">
#           2+ bedrooms
#          </option>
#          <option value="3">
#           3+ bedrooms
#          </option>
#          <option value="4">
#           4+ bedrooms
#          </option>
#          <option value="5">
#           5+ bedrooms
#          </option>
#          <option value="6">
#           6+ bedrooms
#          </option>
#          <option value="7">
#           7+ bedrooms
#          </option>
#          <option value="8">
#           8+ bedrooms
#          </option>
#         </select>
#         <br/>
#         <select class="autosubmit" name="bathrooms">
#          <option value="">
#           all bathrooms
#          </option>
#          <option value="1">
#           1+ bathrooms
#          </option>
#          <option value="2">
#           2+ bathrooms
#          </option>
#          <option value="3">
#           3+ bathrooms
#          </option>
#          <option value="4">
#           4+ bathrooms
#          </option>
#          <option value="5">
#           5+ bathrooms
#          </option>
#          <option value="6">
#           6+ bathrooms
#          </option>
#          <option value="7">
#           7+ bathrooms
#          </option>
#          <option value="8">
#           8+ bathrooms
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup minmax ">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#         <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#        </div>
#        <div class="searchgroup">
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1"/>
#          cats ok
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1"/>
#          dogs ok
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input class="autosubmit" name="is_furnished" type="checkbox" value="1"/>
#          furnished
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1"/>
#          no smoking
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1"/>
#          wheelchair access
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup">
#         <div class="catfilter attr_picker multilink " data-attr="housing_type" data-checked-count="0" id="headerattr_housing_type">
#          <span class="plusminus" id="plusminus_housing_type">
#           +
#          </span>
#          housing type
#         </div>
#         <ul class="attr_list hideme" id="ul_housing_type">
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="apartment_1" name="housing_type" type="checkbox" value="1"/>
#            apartment
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="condo_2" name="housing_type" type="checkbox" value="2"/>
#            condo
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="cottage/cabin_3" name="housing_type" type="checkbox" value="3"/>
#            cottage/cabin
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="duplex_4" name="housing_type" type="checkbox" value="4"/>
#            duplex
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="flat_5" name="housing_type" type="checkbox" value="5"/>
#            flat
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="house_6" name="housing_type" type="checkbox" value="6"/>
#            house
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="in-law_7" name="housing_type" type="checkbox" value="7"/>
#            in-law
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="loft_8" name="housing_type" type="checkbox" value="8"/>
#            loft
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="townhouse_9" name="housing_type" type="checkbox" value="9"/>
#            townhouse
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="manufactured_10" name="housing_type" type="checkbox" value="10"/>
#            manufactured
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="assisted_living_11" name="housing_type" type="checkbox" value="11"/>
#            assisted living
#           </label>
#          </li>
#          <li class="attr_housing_type ">
#           <label data-attr="housing_type">
#            <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="land_12" name="housing_type" type="checkbox" value="12"/>
#            land
#           </label>
#          </li>
#          <li class="selectall js-only attr_housing_type ">
#           <label>
#            <input class="selectallcb multi_checkbox" data-attr="housing_type" type="checkbox"/>
#            <span class="all select_all_housing_type">
#             select all
#            </span>
#            <span class="none deselect_all_housing_type">
#             deselect all
#            </span>
#           </label>
#          </li>
#         </ul>
#         <div class="catfilter attr_picker multilink " data-attr="laundry" data-checked-count="0" id="headerattr_laundry">
#          <span class="plusminus" id="plusminus_laundry">
#           +
#          </span>
#          laundry
#         </div>
#         <ul class="attr_list hideme" id="ul_laundry">
#          <li class="attr_laundry ">
#           <label data-attr="laundry">
#            <input class="multi_checkbox multi_laundry" data-attr="laundry" id="w/d_in_unit_1" name="laundry" type="checkbox" value="1"/>
#            w/d in unit
#           </label>
#          </li>
#          <li class="attr_laundry ">
#           <label data-attr="laundry">
#            <input class="multi_checkbox multi_laundry" data-attr="laundry" id="w/d_hookups_4" name="laundry" type="checkbox" value="4"/>
#            w/d hookups
#           </label>
#          </li>
#          <li class="attr_laundry ">
#           <label data-attr="laundry">
#            <input class="multi_checkbox multi_laundry" data-attr="laundry" id="laundry_in_bldg_2" name="laundry" type="checkbox" value="2"/>
#            laundry in bldg
#           </label>
#          </li>
#          <li class="attr_laundry ">
#           <label data-attr="laundry">
#            <input class="multi_checkbox multi_laundry" data-attr="laundry" id="laundry_on_site_3" name="laundry" type="checkbox" value="3"/>
#            laundry on site
#           </label>
#          </li>
#          <li class="attr_laundry ">
#           <label data-attr="laundry">
#            <input class="multi_checkbox multi_laundry" data-attr="laundry" id="no_laundry_on_site_5" name="laundry" type="checkbox" value="5"/>
#            no laundry on site
#           </label>
#          </li>
#         </ul>
#         <div class="catfilter attr_picker multilink " data-attr="parking" data-checked-count="0" id="headerattr_parking">
#          <span class="plusminus" id="plusminus_parking">
#           +
#          </span>
#          parking
#         </div>
#         <ul class="attr_list hideme" id="ul_parking">
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="carport_1" name="parking" type="checkbox" value="1"/>
#            carport
#           </label>
#          </li>
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="attached_garage_2" name="parking" type="checkbox" value="2"/>
#            attached garage
#           </label>
#          </li>
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="detached_garage_3" name="parking" type="checkbox" value="3"/>
#            detached garage
#           </label>
#          </li>
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="off-street_parking_4" name="parking" type="checkbox" value="4"/>
#            off-street parking
#           </label>
#          </li>
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="street_parking_5" name="parking" type="checkbox" value="5"/>
#            street parking
#           </label>
#          </li>
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="valet_parking_6" name="parking" type="checkbox" value="6"/>
#            valet parking
#           </label>
#          </li>
#          <li class="attr_parking ">
#           <label data-attr="parking">
#            <input class="multi_checkbox multi_parking" data-attr="parking" id="no_parking_7" name="parking" type="checkbox" value="7"/>
#            no parking
#           </label>
#          </li>
#          <li class="selectall js-only attr_parking ">
#           <label>
#            <input class="selectallcb multi_checkbox" data-attr="parking" type="checkbox"/>
#            <span class="all select_all_parking">
#             select all
# ...
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5284698824" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5284712958">
#         <a class="i" data-ids="0:00Z0Z_cxbXD3SxVMW,0:00F0F_54REwJTb9g6,0:00t0t_c9fCk982vIW,0:00V0V_cuSWmWqbjrT,0:00J0J_coOL4xrXGHI,0:00w0w_cQ6CQGGqU9A,0:01616_9KSCjxfmsK4,0:00k0k_2JQICcoux4e,0:00J0J_aeBNUIemStR,0:00Z0Z_4GZyCLOHk7k,0:00A0A_gXVMk5Gux6n" href="/brk/fee/5284712958.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-10-25 14:22" title="Sun 25 Oct 02:22:53 PM">
#            Oct 25
#           </time>
#           <a class="hdrlnk" data-id="5284712958" href="/brk/fee/5284712958.html">
#            Palatial Chic Crisp Like Fresh Linens 3BR+Dining Room Washer Dishwasher Details!
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $3400
#           </span>
#           <span class="housing">
#            / 3br -
#           </span>
#           <span class="pnr">
#            <small>
#             (Park Slope)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5284712958">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5284712958" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5284712958" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5281737806" data-repost-of="5232934529">
#         <a class="i" data-ids="0:00P0P_b2V9PsS4KZR,0:00Q0Q_3bC9hiC0Aqg,0:00N0N_gUHCxgPxHjU,0:00909_d92a46F2G3N,0:00g0g_66WItJaHasX,0:00W0W_g1xuohEbgBx,0:00R0R_5FmxypUjzeh,0:00e0e_evNVjScTWRf,0:00j0j_k3QxRF5hVbg,0:00000_9wQYrmBUHqo,0:00S0S_bvljNx8qtdW" href="/mnh/abo/5281737806.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-10-25 14:22" title="Sun 25 Oct 02:22:46 PM">
#            Oct 25
#           </time>
#           <a class="hdrlnk" data-id="5281737806" href="/mnh/abo/5281737806.html">
#            Place to live with your buds in this B-E-A-U TIFUL Post Grad 3 Bedroom
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $5200
#           </span>
#           <span class="housing">
#            / 3br -
#           </span>
#           <span class="pnr">
#            <small>
#             (East Village)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5281737806">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5281737806" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5281737806" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5284705625">
#         <a class="i" data-ids="0:00F0F_gfrtbTTzA5D,0:00E0E_eYTppMz5ue2,0:00606_9iXfeueoES8,0:00m0m_ehvKbYV0gec,0:00M0M_egvbQMCzzsA,0:00d0d_gI4FoJVl6FF,0:00a0a_2P01j1FCHYQ,0:00c0c_dLIVDNOQAcr,0:00E0E_eYTppMz5ue2,0:00606_9iXfeueoES8,0:00404_4Lr9KmjFRC7,0:00F0F_1rMXtc11wr1,0:00b0b_eYy3Gplc0oQ,0:00i0i_in8HTjwzW0i,0:01111_12oLbZhERwq" href="/fct/abo/5284705625.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-10-25 14:22" title="Sun 25 Oct 02:22:22 PM">
#            Oct 25
#           </time>
#           <a class="hdrlnk" data-id="5284705625" href="/fct/abo/5284705625.html">
#            Sunny 3 rooms and eat in kitchen in Danbury
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $1500
#           </span>
#           <span class="housing">
#            / 2br - 1000ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (28 Davis Street)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5284705625" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5284705625" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5271448834">
#         <a class="i" data-ids="0:01717_7uxVxGFZInX,0:00G0G_6uQeW8GKb4K,0:00W0W_6e9ou81HyJ3,0:00Y0Y_dJbQMMubvpO,0:00i0i_416zgbsZL3D" href="/brk/abo/5271448834.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-10-25 14:22" title="Sun 25 Oct 02:22:19 PM">
#            Oct 25
#           </time>
#           <a class="hdrlnk" data-id="5271448834" href="/brk/abo/5271448834.html">
#            Awesome Design&gt;"&gt;"&gt;",brand new renovation, 3 blocks
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $1995
#           </span>
#           <span class="housing">
#            / 2br -
#           </span>
#           <span class="pnr">
#            <small>
#             (L @ MYRTLE WYCKOFF)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5271448834">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5271448834" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5271448834" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5279642030">
#         <a class="i" data-ids="0:00i0i_dt57VGPieYA,0:00V0V_c92K9DAvAUS,0:00404_arwUYyBo08h,0:00O0O_bD1psjFAbdY,0:00B0B_ikUYSl2ZaJ7,0:00O0O_9bqtL4kwOAa,0:00909_dRnqXfnosbB,0:00X0X_2vieTL2XiEB" href="/brk/abo/5279642030.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-10-25 14:22" title="Sun 25 Oct 02:22:15 PM">
#            Oct 25
#           </time>
#           <a class="hdrlnk" data-id="5279642030" href="/brk/abo/5279642030.html">
#            3 Bedrooms Pulaski St
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2800
#           </span>
#           <span class="housing">
#            / 3br -
#           </span>
#           <span class="pnr">
#            <small>
#             (Bedford-Stuyvesant)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5279642030">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5279642030" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5279642030" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <div data-arealat="40.714199" data-arealon="-74.006401" id="mapcontainer">
#         <div id="noresult_overlay">
#         </div>
#         <div id="noresult_text">
#          <span class="message">
#           No mappable items found
#          </span>
#         </div>
#         <div class="loading" id="map">
#          <div class="closeFS">
#           close fullscreen
#          </div>
#         </div>
#        </div>
#        <div class="toc_legend bottom">
#         <div class="center">
#          <div class="tocview">
#           <span class="buttongroup">
#            <a class="backtotop button" href="#pagecontainer">
#             ^ back to top
#            </a>
#           </span>
#          </div>
#          <div class="tocsort">
#           <span class="buttongroup">
#            <a class="backtotop button" href="#pagecontainer">
#             ^ back to top
#            </a>
#           </span>
#          </div>
#          <span class="paginator buttongroup firstpage">
#           <span class="resulttotal">
#            displaying
#            <span class="displaycount">
#             ...
#            </span>
#            postings
#           </span>
#           <span class="buttons">
#            <a class="button first" href="/search/aap?bedrooms=2&amp;max_price=6000&amp;min_price=1500" title="first page">
#             &lt;&lt;
#            </a>
#            <span class="button first" title="first page">
#             &lt;&lt;
#            </span>
#            <a class="button prev" href="/search/aap?bedrooms=2&amp;max_price=6000&amp;min_price=1500" title="previous page">
#             &lt; prev
#            </a>
#            <span class="button prev" title="previous page">
#             &lt; prev
#            </span>
#            <span class="button pagenum">
#             <span class="range">
#              <span class="rangeFrom">
#               1
#              </span>
#              to
#              <span class="rangeTo">
#               100
#              </span>
#             </span>
#             of
#             <span class="totalcount">
#              2500
#             </span>
#            </span>
#            <a class="button next" href="/search/aap?s=100&amp;bedrooms=2&amp;max_price=6000&amp;min_price=1500" title="next page">
#             next &gt;
#            </a>
#            <span class="button next" title="next page">
#             next &gt;
#            </span>
#           </span>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#      <section class="blurbs">
#      </section>
#      <div id="floater">
#       <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#       <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      </div>
#      <template id="gallerycarousel">
#       <div class="sliderinfo">
#       </div>
#       <div class="sliderback arrow">
#        &lt;
#       </div>
#       <div class="sliderforward arrow">
#        &gt;
#       </div>
#      </template>
#     </form>
#    </div>
#    <div class="mobile-only">
#    </div>
#    <div class="discards footstool no-mobile js-only">
#     <p>
#      <strong class="hidden_count withmap">
#      </strong>
#      <strong class="hidden_count nomap">
#      </strong>
#      dismissed
#     </p>
#     <div class="show-discards-link linklike" role="button" tabindex="0">
#      click to show
#     </div>
#     <div class="hide-discards-link linklike" role="button" tabindex="0">
#      click to hide
#     </div>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://newyork.craigslist.org/search/aap?bedrooms=2&amp;format=rss&amp;min_price=1500">
#       RSS
#      </a>
#      <a href="http://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br/>
#     </span>
#     <ul class="clfooter">
#      <li>
#       © 2015
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="//www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="//www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=074569cf39420adc983cd6cff0604101" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish no-mobile">
#                 <span class="banish" title="hide">[&times;]</span><span class="unbanish" title="unhide">[undo]</span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="star" data-pid="{PostingID}"></span>
#             <span class="postingtitle">
#               <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish no-mobile" data-pid="{PostingID}">
#                   <span class="banish" title="dismiss">[&times;]</span><span class="unbanish" title="allow">[undo]</span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer">
#             <div class="slidernav">
#                 <span class="sliderback">&lt;</span><span class="sliderinfo"></span><span class="sliderforward">&gt;</span>
#             </div>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <abbr class="date timeago" title="{isoPostedDate}">{humanPostedDate}</abbr>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=a7b2d3fe83f7ca7f6ca1a2bfeca7bfbb" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/tocs-concat.min.js?v=becfc7314f9de58c263afe5b105fd42c" type="text/javascript">
#   </script>
#  </body>
# </html>
